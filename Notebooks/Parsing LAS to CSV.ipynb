# %%
import lasio
import pandas as pd

# Load the LAS file
las = lasio.read("WLC_PETRO_COMPUTED_INPUT_1.LAS")

# Convert to a Pandas DataFrame
df = las.df()

# Reset index to make 'DEPTH' a regular column
df.reset_index(inplace=True)

# Export to CSV
df.to_csv("Volve_Well_Log_Data.csv", index=False)
